# %%
import sys
sys.path.append('../')
import giancarlo as gc

# %%
gc.CNumber(-10j) * gc.CNumber(4.5)
# Out:
# -45j

# %%
gc.CNumber(4, 6) ** 2, gc.CNumber(1,2) + gc.CNumber(3,4)
# Out:
# (\frac{4}{9}, \frac{5}{4})

# %%
a = gc.Symbol('a')
b = gc.Symbol('b')
gc.CNumber(-10.5j) * a * a * b * gc.CNumber(4.5)
# Out:
# -47.25j\,a^2\,b

# %%
gc.CNumber(1, 2) * a + b
# Out:
# ( \frac{1}{2}\,a + b )

# %%
(a+b)**2 - a**2
# Out:
# ( 2\,a\,b + b^2 )

# %%
e = a**2 + gc.CNumber(2)*a*b + b**2
e.simplify()
# Out:
# ( ( a^2 + 2\,a\,b + b^2 ) )
